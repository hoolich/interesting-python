# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pymongo import MongoClient
from pandas.io.json import json_normalize

plt.style.use('ggplot')
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['SimHei']  #解决seaborn中文字体显示问题
plt.rc('figure', figsize=(10, 10))  #把plt默认的图片size调大一点
plt.rcParams["figure.dpi"] =mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/0n/6mryfm8x06gfzddk4dympfg80000gn/T/ipykernel_26885/1740136180.py in <module>
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 from pymongo import MongoClient
#       6 from pandas.io.json import json_normalize
#       7
#
# ModuleNotFoundError: No module named 'pymongo'

# %%
conn = MongoClient(host='127.0.0.1', port=27017)  # 实例化MongoClient
db = conn.get_database('Lianjia')  # 连接到Lianjia数据库

zufang = db.get_collection('zufang') # 连接到集合zufang
mon_data = zufang.find()  # 查询这个集合下的所有记录

# %%
data = json_normalize([comment for comment in mon_data])

# %%
data.head()
# Out:
#                         _id bathroom_num bedroom_num bizcircle_name city dist  \
# 0  5c7118b9397be4c52519eec1            1           1            和平里   北京   朝阳
# 1  5c7118bc397be4c52519eec5            1           2            永定门   北京   东城
# 2  5c7118be397be4c52519eec7            1           3            东直门   北京   朝阳
# 3  5c7118c0397be4c52519eec9            1           2            广渠门   北京   朝阳
# 4  5c7118c1397be4c52519eecb            1           1            崇文门   北京   东城
#
#   distance frame_orientation hall_num         house_tag  \
# 0      686               南 北        1     近地铁 集中供暖 随时看房
# 1      478               南 北        1       近地铁 新上 随时看房
# 2     None               南 北        1     近地铁 集中供暖 随时看房
# 3      707              东南 北        1       近地铁 精装 随时看房
# 4      292                 南        0  近地铁 集中供暖 新上 随时看房
#
#                 house_title   latitude  layout   longitude  \
# 0           林调社区 1室1厅 6500元  39.963209  1室1厅1卫  116.432585
# 1  整租 · 东革新里40号院 2室1厅 5300元  39.872127  2室1厅1卫  116.403511
# 2          外大街南北向三居，采光好，精装修  39.947027  3室1厅1卫  116.448231
# 3      整租 · 安化南里 2室1厅 7000元  39.895226  2室1厅1卫  116.441521
# 4    整租 · 兴隆都市馨园 1室0厅 5000元  39.901616  1室0厅1卫  116.420099
#
#                                                m_url rent_area  \
# 0  https://m.lianjia.com/chuzu/bj/zufang/BJ217071...        43
# 1  https://m.lianjia.com/chuzu/bj/zufang/BJ219051...        58
# 2  https://m.lianjia.com/chuzu/bj/zufang/BJ219338...        70
# 3  https://m.lianjia.com/chuzu/bj/zufang/BJ219340...        63
# 4  https://m.lianjia.com/chuzu/bj/zufang/BJ219346...        28
#
#   rent_price_listing rent_price_unit resblock_name type
# 0               6500             元/月          林调社区   整租
# 1               5300             元/月      东革新里40号院   整租
# 2               9700             元/月    东直门外大街(东城）   整租
# 3               7000             元/月          安化南里   整租
# 4               5000             元/月        兴隆都市馨园   整租

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105262 entries, 0 to 105261
# Data columns (total 20 columns):
# _id                   105262 non-null object
# bathroom_num          105262 non-null object
# bedroom_num           105262 non-null object
# bizcircle_name        105262 non-null object
# city                  105262 non-null object
# dist                  105262 non-null object
# distance              57938 non-null object
# frame_orientation     105262 non-null object
# hall_num              105262 non-null object
# house_tag             85090 non-null object
# house_title           105262 non-null object
# latitude              104844 non-null object
# layout                105262 non-null object
# longitude             104844 non-null object
# m_url                 105262 non-null object
# rent_area             105262 non-null object
# rent_price_listing    105262 non-null object
# rent_price_unit       105262 non-null object
# resblock_name         105262 non-null object
# type                  105262 non-null object
# dtypes: object(20)
# memory usage: 16.1+ MB

# %%
# 每个城市各采样3000条数据，保存为csv文件
data_sample = pd.concat([data[data['city']==city].sample(3000) for city in ['北京', '上海', '广州', '深圳']])
data_sample.to_csv('data_sample.csv', index=False)

# %%
# 数据清洗(按列清理)
# 1. 去掉“_id”列
data = data.drop(columns='_id')

# %%
# 2. bathroom_num
data['bathroom_num'].unique()
# Out:
# array(['1', '2', '3', '0', '5', '4', '6', '7', '8', '9', '11'],
#       dtype=object)

# %%
data[data['bathroom_num'].isin(['8','9','11'])]
# Out:
#        bathroom_num bedroom_num bizcircle_name city dist distance  \
# 5988              8           9            四季青   北京   海淀      725
# 10900             9           9            北七家   北京   昌平     None
# 17908             8           8           蓬莱公园   上海   黄浦      517
# 29932             8           6             龙柏   上海   闵行      528
# 33271             8           8           莘闵别墅   上海   松江     None
# 35726             8           8             赵巷   上海   青浦     None
# 55273            11           2             东湖   广州   越秀      260
# 61178             8           9             洛溪   广州   番禺      466
# 63591             8           8             石基   广州   番禺     None
# 65091             8           9          白云大道南   广州   白云      594
# 69840             9           8             永泰   广州   白云     1163
# 71556             8           9            凤凰城   广州   增城     None
# 75268             8          20            滨江东   广州   海珠      968
# 75290             8          20            滨江东   广州   海珠      968
# 75292             8          20            滨江东   广州   海珠      968
# 75293             8          20            滨江东   广州   海珠      968
# 75294             8          20            滨江东   广州   海珠      968
# 75295             8          20            滨江东   广州   海珠      968
# 75296             8          20            滨江东   广州   海珠      968
# 75297             8          20            滨江东   广州   海珠      968
# 75298             8          20            滨江东   广州   海珠      968
# 75299             8          20            滨江东   广州   海珠      968
# 75300             8          20            滨江东   广州   海珠      968
# 75301             8          20            滨江东   广州   海珠      968
# 75304             8          20            滨江东   广州   海珠      968
# 75384             9           9            万胜围   广州   海珠       68
# 87114             8           6             曦城   深圳  宝安区     None
# 94640             9          10             前海   深圳  南山区      293
# 94641             9          10             前海   深圳  南山区      293
# 94650             9          10             前海   深圳  南山区      293
# 94651             9          10             前海   深圳  南山区      293
# 94652             9          10             前海   深圳  南山区      293
# 94653             9          10             前海   深圳  南山区      293
# 94782             9           9             碧海   深圳  宝安区     1136
# 94839             9          10             西乡   深圳  宝安区      293
# 94841             9          10             西乡   深圳  宝安区      293
# 94842             9          10             西乡   深圳  宝安区      293
# 99621             9          10             花木   上海   浦东      404
# 103449            8           7             祝桥   上海   浦东     None
#
#        frame_orientation hall_num               house_tag  \
# 5988               南 西 北        6                      精装
# 10900            东 南 西 北        5                      精装
# 17908                  南        2                  近地铁 新上
# 29932                南 北        3                     近地铁
# 33271                  南        4                    None
# 35726                 未知        6                    None
# 55273                南 北        1                    None
# 61178                 东南        1                     近地铁
# 63591                 东南        3                    None
# 65091                南 北        3                     近地铁
# 69840                 东南        2                    None
# 71556                  南        3                    None
# 75268                  南        2       公寓 近地铁 精装 新上 随时看房
# 75290                  北        2     公寓 近地铁 精装 独立阳台 随时看房
# 75292                  北        2     公寓 近地铁 精装 独立阳台 随时看房
# 75293                  北        2     公寓 近地铁 精装 独立阳台 随时看房
# 75294                  南        2          公寓 近地铁 精装 随时看房
# 75295                  南        2          公寓 近地铁 精装 随时看房
# 75296                  南        2          公寓 近地铁 精装 随时看房
# 75297                  东        2          公寓 近地铁 精装 随时看房
# 75298                  南        2          公寓 近地铁 精装 随时看房
# 75299                  东        2          公寓 近地铁 精装 随时看房
# 75300                  东        2          公寓 近地铁 精装 随时看房
# 75301                  南        2          公寓 近地铁 精装 随时看房
# 75304                  南        2          公寓 近地铁 精装 随时看房
# 75384                  西        0    独立卫生间 月租 近地铁 精装 独立阳台
# 87114              东南 西北        3                    None
# 94640                  东        0  独立卫生间 近地铁 精装 独立阳台 随时看房
# 94641                  东        0  独立卫生间 近地铁 精装 独立阳台 随时看房
# 94650                  东        0  独立卫生间 近地铁 精装 独立阳台 随时看房
# 94651                  东        0  独立卫生间 近地铁 精装 独立阳台 随时看房
# 94652                  东        0  独立卫生间 近地铁 精装 独立阳台 随时看房
# 94653                  东        0  独立卫生间 近地铁 精装 独立阳台 随时看房
# 94782                  南        0         独立卫生间 近地铁 精装 新上
# 94839                  南        1    公寓 独立卫生间 近地铁 精装 随时看房
# 94841                  南        1    公寓 独立卫生间 近地铁 精装 随时看房
# 94842                  南        1    公寓 独立卫生间 近地铁 精装 随时看房
# 99621                  南        5                     近地铁
# 103449               南 北        3                    None
#
#                                  house_title         latitude   layout  \
# 5988    整租 · wehoue 城市别墅 联排别墅 私家电梯使用面积1200平米        39.947186   9室6厅8卫
# 10900             整租 · 精装修独栋别墅，家具家电齐全，可直接入住！        40.146554   9室5厅9卫
# 17908                        华浩苑 8室2厅 13500元        31.213343   8室2厅8卫
# 29932          整租 · 性价别墅，可整租可分层出租，价格可谈，看房方便！         31.18634   6室3厅8卫
# 33271             桃花源田庄 精装修 拎包入住 可办公可居家 看房随时        31.101212   8室4厅8卫
# 35726            整租 · 御湖香水湾，水景独栋，大花园，业主诚意出租。        31.158286   8室6厅8卫
# 55273                           大沙头路两房 采光通风好        23.120535  2室1厅11卫
# 61178                       海天花园 9室1厅 15000元         23.05049   9室1厅8卫
# 63591                       富怡四区 8室3厅 25000元        22.965311   8室3厅8卫
# 65091                     珠江岭南苑  南北向 视野开阔景观好        23.202732   9室3厅8卫
# 69840                        白云堡别墅 南北通透 安静宜居        23.231221   8室2厅9卫
# 71556                  碧桂园凤凰城凤凰苑 9室3厅 88000元        23.138568   9室3厅8卫
# 75268                     合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75290                     合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75292                     合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75293                     合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75294                     合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75295                     合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75296                     合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75297                     合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75298                     合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75299                     合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75300                     合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75301                     合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75304                     合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75384                 合租 · 雅郡花园会展新世界水蓝郡 9室0厅        23.102356   9室0厅9卫
# 87114             曦城别墅四期 端头独栋别墅 共四层 家私全齐 带花园         22.60085   6室3厅8卫
# 94640                     合租 · 御海新苑 10室0厅 复式         22.53626  10室0厅9卫
# 94641                     合租 · 御海新苑 10室0厅 复式         22.53626  10室0厅9卫
# 94650                     合租 · 御海新苑 10室0厅 复式         22.53626  10室0厅9卫
# 94651                     合租 · 御海新苑 10室0厅 复式         22.53626  10室0厅9卫
# 94652                     合租 · 御海新苑 10室0厅 复式         22.53626  10室0厅9卫
# 94653                     合租 · 御海新苑 10室0厅 复式         22.53626  10室0厅9卫
# 94782                      合租 · 浪漫港湾 9室0厅 复式  22.566944859141   9室0厅9卫
# 94839                     合租 · 雅涛花园 10室1厅 复式  22.572475888201  10室1厅9卫
# 94841                     合租 · 雅涛花园 10室1厅 复式  22.572475888201  10室1厅9卫
# 94842                     合租 · 雅涛花园 10室1厅 复式  22.572475888201  10室1厅9卫
# 99621                花木路1701号 15房间9卫 330000元        31.220902  10室5厅9卫
# 103449                      东海御庭 7室3厅 16000元        31.214139   7室3厅8卫
#
#               longitude                                              m_url  \
# 5988         116.275381  https://m.lianjia.com/chuzu/bj/zufang/BJ213593...
# 10900        116.418277  https://m.lianjia.com/chuzu/bj/zufang/BJ203027...
# 17908        121.491824  https://m.lianjia.com/chuzu/sh/zufang/SH219612...
# 29932        121.373958  https://m.lianjia.com/chuzu/sh/zufang/SH215562...
# 33271        121.354455  https://m.lianjia.com/chuzu/sh/zufang/SH219030...
# 35726        121.248358  https://m.lianjia.com/chuzu/sh/zufang/SH192424...
# 55273        113.290942  https://m.lianjia.com/chuzu/gz/zufang/GZ216230...
# 61178        113.301623  https://m.lianjia.com/chuzu/gz/zufang/GZ212158...
# 63591        113.447405  https://m.lianjia.com/chuzu/gz/zufang/GZ214634...
# 65091        113.286666  https://m.lianjia.com/chuzu/gz/zufang/GZ202798...
# 69840        113.318378  https://m.lianjia.com/chuzu/gz/zufang/GZ202798...
# 71556        113.588147  https://m.lianjia.com/chuzu/gz/zufang/GZ213605...
# 75268        113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ219842...
# 75290        113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202833...
# 75292        113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202833...
# 75293        113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202833...
# 75294        113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202833...
# 75295        113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202833...
# 75296        113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202833...
# 75297        113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202833...
# 75298        113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202833...
# 75299        113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202833...
# 75300        113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202833...
# 75301        113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202833...
# 75304        113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ210490...
# 75384        113.392137  https://m.lianjia.com/chuzu/gz/zufang/GZ211082...
# 87114         113.91623  https://m.lianjia.com/chuzu/sz/zufang/SZ210364...
# 94640        113.920491  https://m.lianjia.com/chuzu/sz/zufang/SZ219105...
# 94641        113.920491  https://m.lianjia.com/chuzu/sz/zufang/SZ219105...
# 94650        113.920491  https://m.lianjia.com/chuzu/sz/zufang/SZ219105...
# 94651        113.920491  https://m.lianjia.com/chuzu/sz/zufang/SZ219105...
# 94652        113.920491  https://m.lianjia.com/chuzu/sz/zufang/SZ219105...
# 94653        113.920491  https://m.lianjia.com/chuzu/sz/zufang/SZ219105...
# 94782   113.87520983434  https://m.lianjia.com/chuzu/sz/zufang/SZ219697...
# 94839   113.87775428181  https://m.lianjia.com/chuzu/sz/zufang/SZ218825...
# 94841   113.87775428181  https://m.lianjia.com/chuzu/sz/zufang/SZ218825...
# 94842   113.87775428181  https://m.lianjia.com/chuzu/sz/zufang/SZ218825...
# 99621        121.570658  https://m.lianjia.com/chuzu/sh/zufang/SH212387...
# 103449       121.776494  https://m.lianjia.com/chuzu/sh/zufang/SH206789...
#
#        rent_area rent_price_listing rent_price_unit resblock_name type
# 5988         318             158000             元/月       Wehouse   整租
# 10900        544              40000             元/月          麦卡伦地   整租
# 17908        246              13500             元/月           华浩苑   整租
# 29932        949              75000             元/月          汇金公寓   整租
# 33271        504              48000             元/月         桃花源田庄   整租
# 35726        498              30000             元/月           香水湾   整租
# 55273         60               4000             元/月          大沙头路   整租
# 61178        150              15000             元/月          海天花园   整租
# 63591        604              25000             元/月          富怡四区   整租
# 65091        500              80000             元/月         珠江岭南苑   整租
# 69840        600              43800             元/月      白云堡豪苑白轩径   整租
# 71556        850              88000             元/月     碧桂园凤凰城凤凰苑   整租
# 75268         10               1300             元/月          珠江广场   合租
# 75290         10               1600             元/月          珠江广场   合租
# 75292         12               1800             元/月          珠江广场   合租
# 75293         15               2500             元/月          珠江广场   合租
# 75294         12               1600             元/月          珠江广场   合租
# 75295         15               1600             元/月          珠江广场   合租
# 75296         23               2800             元/月          珠江广场   合租
# 75297         13               1500             元/月          珠江广场   合租
# 75298         10               1500             元/月          珠江广场   合租
# 75299         23               2200             元/月          珠江广场   合租
# 75300         18               1600             元/月          珠江广场   合租
# 75301         38               1700             元/月          珠江广场   合租
# 75304         35               2800             元/月          珠江广场   合租
# 75384          6               2080             元/月  雅郡花园会展新世界水蓝郡   合租
# 87114        418             100000             元/月     招商华侨城曦城四期   整租
# 94640          8               1800             元/月          御海新苑   合租
# 94641         12               2480             元/月          御海新苑   合租
# 94650          9               1600             元/月          御海新苑   合租
# 94651          8               1980             元/月          御海新苑   合租
# 94652          8               1980             元/月          御海新苑   合租
# 94653         12               2600             元/月          御海新苑   合租
# 94782         16               1800             元/月          浪漫港湾   合租
# 94839         15               1480             元/月          雅涛花园   合租
# 94841         16               1680             元/月          雅涛花园   合租
# 94842         12               1380             元/月          雅涛花园   合租
# 99621        581             330000             元/月      花木路1701号   整租
# 103449       767              16000             元/月          东海御庭   整租

# %%
# 除了55273行是异常数据外，其它数据都正常
data = data.drop([55273])

# %%
# 3. bedroom_num
data['bedroom_num'].unique()
# Out:
# array(['1', '2', '3', '4', '6', '5', '9', '7', '8', '0', '10', '12', '15',
#        '20', '14', '11', '13'], dtype=object)

# %%
# 没有异常数据，只是很多10室以上都是专门用来合租的
data[data['bedroom_num'].isin(['10','11','12','13','14','15','20'])]
# Out:
#       bathroom_num bedroom_num bizcircle_name city dist distance  \
# 21378            4          10             长征   上海   普陀     1125
# 31034            3          10           嘉定新城   上海   嘉定      405
# 58474            3          12            滨江东   广州   海珠      711
# 60547            1          15             会江   广州   番禺     None
# 75268            8          20            滨江东   广州   海珠      968
# 75290            8          20            滨江东   广州   海珠      968
# 75292            8          20            滨江东   广州   海珠      968
# 75293            8          20            滨江东   广州   海珠      968
# 75294            8          20            滨江东   广州   海珠      968
# 75295            8          20            滨江东   广州   海珠      968
# 75296            8          20            滨江东   广州   海珠      968
# 75297            8          20            滨江东   广州   海珠      968
# 75298            8          20            滨江东   广州   海珠      968
# 75299            8          20            滨江东   广州   海珠      968
# 75300            8          20            滨江东   广州   海珠      968
# 75301            8          20            滨江东   广州   海珠      968
# 75302            4          10            滨江东   广州   海珠      968
# 75303            4          10            滨江东   广州   海珠      968
# 75304            8          20            滨江东   广州   海珠      968
# 75308            4          10            滨江东   广州   海珠      968
# 75309            4          10            滨江东   广州   海珠      968
# 75310            4          10            滨江东   广州   海珠      968
# 75311            4          10            滨江东   广州   海珠      968
# 75312            4          10            滨江东   广州   海珠      968
# 75313            4          10            滨江东   广州   海珠      968
# 75314            4          10            滨江东   广州   海珠      968
# 81539            2          14             前海   深圳  南山区     None
# 86039            3          10             西乡   深圳  宝安区       38
# 87425            7          10           布吉大芬   深圳  龙岗区      582
# 88091            7          11             坂田   深圳  龙岗区      495
# 88713            6          11           大运新城   深圳  龙岗区      793
# 89813            4          11          龙岗中心城   深圳  龙岗区     None
# 94640            9          10             前海   深圳  南山区      293
# 94641            9          10             前海   深圳  南山区      293
# 94650            9          10             前海   深圳  南山区      293
# 94651            9          10             前海   深圳  南山区      293
# 94652            9          10             前海   深圳  南山区      293
# 94653            9          10             前海   深圳  南山区      293
# 94839            9          10             西乡   深圳  宝安区      293
# 94841            9          10             西乡   深圳  宝安区      293
# 94842            9          10             西乡   深圳  宝安区      293
# 94857            3          12             西乡   深圳  宝安区       38
# 95081            3          13             横岗   深圳  龙岗区       10
# 99621            9          10             花木   上海   浦东      404
#
#       frame_orientation hall_num               house_tag  \
# 21378                 南        2                      新上
# 31034                 南        4                  近地铁 精装
# 58474                 北        2                  近地铁 精装
# 60547                 南        1                      精装
# 75268                 南        2       公寓 近地铁 精装 新上 随时看房
# 75290                 北        2     公寓 近地铁 精装 独立阳台 随时看房
# 75292                 北        2     公寓 近地铁 精装 独立阳台 随时看房
# 75293                 北        2     公寓 近地铁 精装 独立阳台 随时看房
# 75294                 南        2          公寓 近地铁 精装 随时看房
# 75295                 南        2          公寓 近地铁 精装 随时看房
# 75296                 南        2          公寓 近地铁 精装 随时看房
# 75297                 东        2          公寓 近地铁 精装 随时看房
# 75298                 南        2          公寓 近地铁 精装 随时看房
# 75299                 东        2          公寓 近地铁 精装 随时看房
# 75300                 东        2          公寓 近地铁 精装 随时看房
# 75301                 南        2          公寓 近地铁 精装 随时看房
# 75302                 东        2          公寓 近地铁 精装 随时看房
# 75303                 西        2          公寓 近地铁 精装 随时看房
# 75304                 南        2          公寓 近地铁 精装 随时看房
# 75308                 南        2          公寓 近地铁 精装 随时看房
# 75309                 东        2          公寓 近地铁 精装 随时看房
# 75310                 东        2     公寓 近地铁 精装 独立阳台 随时看房
# 75311                 北        2          公寓 近地铁 精装 随时看房
# 75312                 北        2          公寓 近地铁 精装 随时看房
# 75313                 北        2          公寓 近地铁 精装 随时看房
# 75314                 北        2          公寓 近地铁 精装 随时看房
# 81539                 南        5                 新上 随时看房
# 86039                东南        1                近地铁 随时看房
# 87425                东南        3                     近地铁
# 88091                 南        1                     近地铁
# 88713                东南        3                     近地铁
# 89813                 南        6                      新上
# 94640                 东        0  独立卫生间 近地铁 精装 独立阳台 随时看房
# 94641                 东        0  独立卫生间 近地铁 精装 独立阳台 随时看房
# 94650                 东        0  独立卫生间 近地铁 精装 独立阳台 随时看房
# 94651                 东        0  独立卫生间 近地铁 精装 独立阳台 随时看房
# 94652                 东        0  独立卫生间 近地铁 精装 独立阳台 随时看房
# 94653                 东        0  独立卫生间 近地铁 精装 独立阳台 随时看房
# 94839                 南        1    公寓 独立卫生间 近地铁 精装 随时看房
# 94841                 南        1    公寓 独立卫生间 近地铁 精装 随时看房
# 94842                 南        1    公寓 独立卫生间 近地铁 精装 随时看房
# 94857                东南        1            公寓 月租 近地铁 精装
# 95081                 南        1       月租 近地铁 精装 新上 随时看房
# 99621                 南        5                     近地铁
#
#                            house_title         latitude   layout  \
# 21378        名邸联排别墅，三层十室，精装全配拎包入住，诚意出租      31.25033037  10室2厅4卫
# 31034        整租 · 阳光葡提公馆 14房间3卫 13500元      31.33711314  10室4厅3卫
# 58474                  整租 · 珠江帝景 装修保养好        23.110206  12室2厅3卫
# 60547  整租 · 公寓   电梯房    干净舒适      格局方正        23.008658  15室1厅1卫
# 75268               合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75290               合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75292               合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75293               合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75294               合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75295               合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75296               合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75297               合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75298               合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75299               合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75300               合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75301               合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75302                  合租 · 珠江广场 10室2厅        23.108886  10室2厅4卫
# 75303                  合租 · 珠江广场 10室2厅        23.108886  10室2厅4卫
# 75304               合租 · 珠江广场 20室2厅 复式        23.108886  20室2厅8卫
# 75308                  合租 · 珠江广场 10室2厅        23.108886  10室2厅4卫
# 75309                  合租 · 珠江广场 10室2厅        23.108886  10室2厅4卫
# 75310                  合租 · 珠江广场 10室2厅        23.108886  10室2厅4卫
# 75311                  合租 · 珠江广场 10室2厅        23.108886  10室2厅4卫
# 75312                  合租 · 珠江广场 10室2厅        23.108886  10室2厅4卫
# 75313                  合租 · 珠江广场 10室2厅        23.108886  10室2厅4卫
# 75314                  合租 · 珠江广场 10室2厅        23.108886  10室2厅4卫
# 81539               月亮湾山庄 14室5厅 18000元        22.496679  14室5厅2卫
# 86039             合正汇一城 10室1厅 2000元 跃层         22.58227  10室1厅3卫
# 87425                龙泉别墅 10室3厅 25000元        22.622112  10室3厅7卫
# 88091      坂田五和双地铁口 小区环境好 绿化高 停车位充足 复式        22.631307  11室1厅7卫
# 88713       大运地铁站 星河时代 六层连排别墅 拎包入住  复式        22.698575  11室3厅6卫
# 89813                君悦龙庭 11室6厅 26000元        22.731861  11室6厅4卫
# 94640               合租 · 御海新苑 10室0厅 复式         22.53626  10室0厅9卫
# 94641               合租 · 御海新苑 10室0厅 复式         22.53626  10室0厅9卫
# 94650               合租 · 御海新苑 10室0厅 复式         22.53626  10室0厅9卫
# 94651               合租 · 御海新苑 10室0厅 复式         22.53626  10室0厅9卫
# 94652               合租 · 御海新苑 10室0厅 复式         22.53626  10室0厅9卫
# 94653               合租 · 御海新苑 10室0厅 复式         22.53626  10室0厅9卫
# 94839               合租 · 雅涛花园 10室1厅 复式  22.572475888201  10室1厅9卫
# 94841               合租 · 雅涛花园 10室1厅 复式  22.572475888201  10室1厅9卫
# 94842               合租 · 雅涛花园 10室1厅 复式  22.572475888201  10室1厅9卫
# 94857              合租 · 合正汇一城 12室1厅 错层         22.58227  12室1厅3卫
# 95081                   合租 · 振业城 13室1厅  22.642763067327  13室1厅3卫
# 99621          花木路1701号 15房间9卫 330000元        31.220902  10室5厅9卫
#
#              longitude                                              m_url  \
# 21378      121.3845601  https://m.lianjia.com/chuzu/sh/zufang/SH219480...
# 31034      121.2949683  https://m.lianjia.com/chuzu/sh/zufang/SH213808...
# 58474       113.333391  https://m.lianjia.com/chuzu/gz/zufang/GZ202798...
# 60547       113.310885  https://m.lianjia.com/chuzu/gz/zufang/GZ213259...
# 75268       113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ219842...
# 75290       113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202833...
# 75292       113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202833...
# 75293       113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202833...
# 75294       113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202833...
# 75295       113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202833...
# 75296       113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202833...
# 75297       113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202833...
# 75298       113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202833...
# 75299       113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202833...
# 75300       113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202833...
# 75301       113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202833...
# 75302       113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202835...
# 75303       113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202835...
# 75304       113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ210490...
# 75308       113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202835...
# 75309       113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202835...
# 75310       113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202835...
# 75311       113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202835...
# 75312       113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202835...
# 75313       113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202835...
# 75314       113.316313  https://m.lianjia.com/chuzu/gz/zufang/GZ202835...
# 81539       113.894108  https://m.lianjia.com/chuzu/sz/zufang/SZ219831...
# 86039       113.870734  https://m.lianjia.com/chuzu/sz/zufang/SZ219143...
# 87425       114.151512  https://m.lianjia.com/chuzu/sz/zufang/SZ213328...
# 88091       114.071361  https://m.lianjia.com/chuzu/sz/zufang/SZ218027...
# 88713       114.233453  https://m.lianjia.com/chuzu/sz/zufang/SZ218156...
# 89813       114.229081  https://m.lianjia.com/chuzu/sz/zufang/SZ219781...
# 94640       113.920491  https://m.lianjia.com/chuzu/sz/zufang/SZ219105...
# 94641       113.920491  https://m.lianjia.com/chuzu/sz/zufang/SZ219105...
# 94650       113.920491  https://m.lianjia.com/chuzu/sz/zufang/SZ219105...
# 94651       113.920491  https://m.lianjia.com/chuzu/sz/zufang/SZ219105...
# 94652       113.920491  https://m.lianjia.com/chuzu/sz/zufang/SZ219105...
# 94653       113.920491  https://m.lianjia.com/chuzu/sz/zufang/SZ219105...
# 94839  113.87775428181  https://m.lianjia.com/chuzu/sz/zufang/SZ218825...
# 94841  113.87775428181  https://m.lianjia.com/chuzu/sz/zufang/SZ218825...
# 94842  113.87775428181  https://m.lianjia.com/chuzu/sz/zufang/SZ218825...
# 94857       113.870734  https://m.lianjia.com/chuzu/sz/zufang/SZ213670...
# 95081  114.18517356632  https://m.lianjia.com/chuzu/sz/zufang/SZ219611...
# 99621       121.570658  https://m.lianjia.com/chuzu/sh/zufang/SH212387...
#
#       rent_area rent_price_listing rent_price_unit   resblock_name type
# 21378       228              23000             元/月        祥和名邸(别墅)   整租
# 31034       312              13500             元/月          阳光葡提公馆   整租
# 58474       530              50000             元/月  珠江帝景苑克莱国际公寓灏景轩   整租
# 60547       408              25000             元/月          敏捷御峰国际   整租
# 75268        10               1300             元/月            珠江广场   合租
# 75290        10               1600             元/月            珠江广场   合租
# 75292        12               1800             元/月            珠江广场   合租
# 75293        15               2500             元/月            珠江广场   合租
# 75294        12               1600             元/月            珠江广场   合租
# 75295        15               1600             元/月            珠江广场   合租
# 75296        23               2800             元/月            珠江广场   合租
# 75297        13               1500             元/月            珠江广场   合租
# 75298        10               1500             元/月            珠江广场   合租
# 75299        23               2200             元/月            珠江广场   合租
# 75300        18               1600             元/月            珠江广场   合租
# 75301        38               1700             元/月            珠江广场   合租
# 75302        15               1400             元/月            珠江广场   合租
# 75303        18               1800             元/月            珠江广场   合租
# 75304        35               2800             元/月            珠江广场   合租
# 75308        12               1500             元/月            珠江广场   合租
# 75309        16               1800             元/月            珠江广场   合租
# 75310        23               2200             元/月            珠江广场   合租
# 75311        20               2500             元/月            珠江广场   合租
# 75312        18               2200             元/月            珠江广场   合租
# 75313        28               2600             元/月            珠江广场   合租
# 75314        16               2100             元/月            珠江广场   合租
# 81539       259              18000             元/月           月亮湾山庄   整租
# 86039       148               2000             元/月           合正汇一城   整租
# 87425       333              25000             元/月            龙泉别墅   整租
# 88091       227              32000             元/月        十二橡树庄园一期   整租
# 88713       294              35000             元/月            星河时代   整租
# 89813       183              26000             元/月            君悦龙庭   整租
# 94640         8               1800             元/月            御海新苑   合租
# 94641        12               2480             元/月            御海新苑   合租
# 94650         9               1600             元/月            御海新苑   合租
# 94651         8               1980             元/月            御海新苑   合租
# 94652         8               1980             元/月            御海新苑   合租
# 94653        12               2600             元/月            御海新苑   合租
# 94839        15               1480             元/月            雅涛花园   合租
# 94841        16               1680             元/月            雅涛花园   合租
# 94842        12               1380             元/月            雅涛花园   合租
# 94857        25               2299             元/月           合正汇一城   合租
# 95081        15               1480             元/月             振业城   合租
# 99621       581             330000             元/月        花木路1701号   整租

# %%
# 4. distance
data['frame_orientation'].unique()  # 这个数据太乱了，要用的时候再处理吧
# Out:
# array(['南 北', '东南 北', '南', '北', '西南', '东 西', '西', '东南', '东', '西北', '东 北',
#        '东北', '东 南 北', '东 南 西', '南 西 北', '东南 西北 北', '西 北', '南 西', '南 西南',
#        '东 西 北', '东 南', '东 东南', '东 西南', '西南 西', '东 南 西 北', '东 东南 南',
#        '东 西北', '西 西北', '西南 北', '东南 南', '东南 西', '西北 北', '东 西 西北', '西南 东北',
#        '东 东北', '西 东北', '南 西北', '东南 西北', '东南 西南', '西南 西北', '东南 西南 西 北',
#        '东南 东北', '西北 东北', '东南 南 西南', '东 北 东北', '东 西南 西', '南 东北', '东南 西 北',
#        '东 南 西南', '南 西北 北', '西 西北 北', '北 东北', '东南 西南 西', '未知', '南 西南 北',
#        '东南 南 北', '东 东南 南 西南', '南 西南 西 北', '东 西北 北', '东 南 东北', '东 南 西北',
#        '', ' 东南 南', ' 南 西南 西北', '东 东南 南 西南 西 西北 北 东北',
#        ' 东 东南 南 西南 西 西北 北 东北', '西南 西 西北 北', ' 南', ' 东南', '东南 南 西北',
#        ' 东南 北', '南 北 东北', ' 东 东南', '南 西南 西', '东南 西南 西北', ' 东 东南 西南',
#        ' 东 南', ' 东', '东南 南 西南 西 西北 北 东北', '东 东南 南 北', '东 东南 北', ' 东 南 西',
#        '东 南 西南 西', '东 东南 南 西南 西 西北 北', '东 东南 南 西 北', '东 东南 南 西 西北',
#        '东 东南 南 西南 西', '东 东南 南 西南 西北', '东 东南 南 西 西北 北', '东 东南 南 西南 西 西北',
#        '东 东南 南 西南 西 北', '东 东南 南 西 西北 北 东北', '东 东南 南 西北 北', '东 东南 西南',
#        '南 西南 西北', '东南 南 西', '东 东南 南 西南 西北 北', '东 东南 南 西南 西北 北 东北',
#        '东 东南 南 西 东北', '东南 南 西南 西', '东南 南 西南 北', '东 东南 南 西南 北', '东 东南 西',
#        '东 东南 南 西', '东南 南 西南 西 北', '东南 南 西南 西北 东北', '东南 南 西南 西北',
#        '东南 南 西 西北', '东南 南 西南 北 东北', ' 南 北', '东 东南 西 北', '南 西 西北',
#        '东 东南 西南 西', '东 东南 南 西北', '东 东南 南 西南 西 西北 东北', '东 东南 西南 西 西北',
#        '东南 西南 西 西北', '东 西南 西 西北', '东南 南 西北 东北', '东 东南 西 西北',
#        '东南 南 西南 西 西北', '西南 西北 北', '东 东南 东北', ' 西北', '东南 西南 西北 东北',
#        '东南 南 西南 西 西北 东北', '东 东南 西北', '东 东南 西南 北', ' 东 南 北', ' 南 西南',
#        ' 东南 南 西南 西', ' 南 西南 西北 北', ' 东 南 西南', ' 东 东南 南', '西南 西 西北', ' 西南',
#        '东南 西南 北', '东南 南 西南 西 西北 北', '东 南 西南 西 西北', '东南 南 西 西北 北 东北',
#        '东 东南 西南 西北 北 东北', '东南 西南 西北 北 东北', '南 西南 北 东北', '西南 西 东北',
#        '东 东南 西 西北 北', '东南 南 西 西北 北', ' 东南 西北', '东 东南 西南 西 西北 北',
#        '东 东南 西南 西北 北', '东 南 西南 西 北', ' 东 西', '东 东南 南 北 东北', '南 西南 西 西北',
#        '西北 北 东北', '东 西 西北 北 东北', '东南 南 西北 北 东北', '东 东南 西南 西北 东北',
#        '东南 西北 东北', ' 南 西 北', '东 西南 西北 北', '东 南 西 北 东北', '东南 西南 西 东北',
#        '东南 西 西北 东北', '东 南 西 西北', '东 南 西 西北 北', '东南 西南 东北',
#        '东 东南 西南 西 西北 东北', '西南 西北 东北', '东南 南 东北', ' 东南 西南 东北', ' 东南 西 东北',
#        '东 南 西北 北', ' 东 南 东北', ' 东南 西南', '东 西南 东北', '东 东南 南 西 北 东北',
#        '东南 西北 北 东北', '东 南 西南 北', '东 东南 南 西南 北 东北', '东南 西 西北', '东 西 西北 北',
#        '西南 西 北 东北', '东南 南 西北 北', '西南 西 北', '东 东南 南 西南 西 东北',
#        '东南 西南 西 西北 北 东北', '东南 南 西南 东北', '东南 西南 西北 北', '东 东南 西南 西北',
#        '东 西北 东北', ' 东南 西', '东 西南 西北', '东 西南 北', '东南 西南 西 西北 东北',
#        ' 东南 南 西', ' 东 南 西 北', '东南 南 西 北', '东南 南 西南 西北 北', '东南 西 东北',
#        ' 东北', '东 东南 南 东北', '西 西北 北 东北', ' 西', '南 西北 东北', ' 南 西北 北',
#        '东南 南 北 东北'], dtype=object)

# %%
# 5. hall_num
data['hall_num'].unique()
# Out:
# array(['1', '0', '2', '3', '5', '4', '6', '11'], dtype=object)

# %%
data[data['hall_num'].isin(['6','11'])]
# Out:
#       bathroom_num bedroom_num bizcircle_name city dist distance  \
# 5988             8           9            四季青   北京   海淀      725
# 28085            6           4           新江湾城   上海   杨浦     None
# 35726            8           8             赵巷   上海   青浦     None
# 59223            1           2            江南西   广州   海珠      444
# 89813            4          11          龙岗中心城   深圳  龙岗区     None
# 95369            6           6           龙华中心   深圳  龙华区      151
# 95370            6           6           龙华中心   深圳  龙华区      151
# 95371            6           6           龙华中心   深圳  龙华区      151
# 95372            6           6           龙华中心   深圳  龙华区      151
# 95378            6           6           龙华中心   深圳  龙华区      151
# 95379            6           6           龙华中心   深圳  龙华区      151
#
#       frame_orientation hall_num             house_tag  \
# 5988              南 西 北        6                    精装
# 28085               南 北        6                    精装
# 35726                未知        6                  None
# 59223                东南       11                   近地铁
# 89813                 南        6                    新上
# 95369                 南        6  公寓 独立卫生间 近地铁 精装 独立阳台
# 95370                 南        6  公寓 独立卫生间 近地铁 精装 独立阳台
# 95371                 南        6       公寓 独立卫生间 近地铁 精装
# 95372                西北        6       公寓 独立卫生间 近地铁 精装
# 95378                西北        6       公寓 独立卫生间 近地铁 精装
# 95379                 南        6       公寓 独立卫生间 近地铁 精装
#
#                                 house_title     latitude   layout  \
# 5988   整租 · wehoue 城市别墅 联排别墅 私家电梯使用面积1200平米    39.947186   9室6厅8卫
# 28085            整租 · 联排自住小区环境静谧看房便利带车位 近商圈  31.31852594   4室6厅6卫
# 35726           整租 · 御湖香水湾，水景独栋，大花园，业主诚意出租。    31.158286   8室6厅8卫
# 59223                         江南西南丰阁 电梯实用二房    23.100317  2室11厅1卫
# 89813                     君悦龙庭 11室6厅 26000元    22.731861  11室6厅4卫
# 95369                     合租 · 港铁天颂 6室6厅 复式    22.651492   6室6厅6卫
# 95370                     合租 · 港铁天颂 6室6厅 复式    22.651492   6室6厅6卫
# 95371                     合租 · 港铁天颂 6室6厅 复式    22.651492   6室6厅6卫
# 95372                     合租 · 港铁天颂 6室6厅 复式    22.651492   6室6厅6卫
# 95378                     合租 · 港铁天颂 6室6厅 复式    22.651492   6室6厅6卫
# 95379                     合租 · 港铁天颂 6室6厅 复式    22.651492   6室6厅6卫
#
#          longitude                                              m_url  \
# 5988    116.275381  https://m.lianjia.com/chuzu/bj/zufang/BJ213593...
# 28085  121.5053126  https://m.lianjia.com/chuzu/sh/zufang/SH203684...
# 35726   121.248358  https://m.lianjia.com/chuzu/sh/zufang/SH192424...
# 59223   113.276289  https://m.lianjia.com/chuzu/gz/zufang/GZ203033...
# 89813   114.229081  https://m.lianjia.com/chuzu/sz/zufang/SZ219781...
# 95369   114.017863  https://m.lianjia.com/chuzu/sz/zufang/SZ219042...
# 95370   114.017863  https://m.lianjia.com/chuzu/sz/zufang/SZ219042...
# 95371   114.017863  https://m.lianjia.com/chuzu/sz/zufang/SZ219042...
# 95372   114.017863  https://m.lianjia.com/chuzu/sz/zufang/SZ219042...
# 95378   114.017863  https://m.lianjia.com/chuzu/sz/zufang/SZ219042...
# 95379   114.017863  https://m.lianjia.com/chuzu/sz/zufang/SZ219042...
#
#       rent_area rent_price_listing rent_price_unit resblock_name type
# 5988        318             158000             元/月       Wehouse   整租
# 28085       450              30000             元/月    江湾尊堡别墅(别墅)   整租
# 35726       498              30000             元/月           香水湾   整租
# 59223        66               4000             元/月           南丰阁   整租
# 89813       183              26000             元/月          君悦龙庭   整租
# 95369        35               3580             元/月          港铁天颂   合租
# 95370        45               4980             元/月          港铁天颂   合租
# 95371        45               4680             元/月          港铁天颂   合租
# 95372        25               2380             元/月          港铁天颂   合租
# 95378        28               2800             元/月          港铁天颂   合租
# 95379        35               3200             元/月          港铁天颂   合租

# %%
# 59223行是异常数据，删去
data = data.drop([59223])

# %%
# 6. rent_area
data.sample(5)['rent_area']
# Out:
# 24116     42
# 61023     88
# 102182    40
# 3203      58
# 15365     53
# Name: rent_area, dtype: object

# %%
# rent_area字段有些填写的是一个范围，比如23-25平房米，后期转换成“float”类型的时候不好转换，考虑取平均值
def get_aver(data):
    if isinstance(data, str) and '-' in data:
        low, high = data.split('-')
        return (int(low)+int(high))/2
    else:
        return int(data)


data['rent_area'] = data['rent_area'].apply(get_aver)

# %%
data[data['rent_area'] < 5]
# Out:
#       bathroom_num bedroom_num bizcircle_name city dist distance  \
# 33264            1           2             九亭   上海   松江       33
# 46990            1           2             东圃   广州   天河      490
#
#       frame_orientation hall_num house_tag        house_title   latitude  \
# 33264                 南        2       近地铁  上海青年城 4房间1卫 4800元  31.143103
# 46990                 东        1       近地铁  美林湖畔花园 2室1厅 5200元  23.115432
#
#        layout   longitude                                              m_url  \
# 33264  2室2厅1卫  121.325136  https://m.lianjia.com/chuzu/sh/zufang/SH218622...
# 46990  2室1厅1卫  113.421825  https://m.lianjia.com/chuzu/gz/zufang/GZ217437...
#
#        rent_area rent_price_listing rent_price_unit resblock_name type
# 33264        1.0               4800             元/月         上海青年城   整租
# 46990        1.0               5200             元/月        美林湖畔花园   整租

# %%
# 房间只有1平米，是异常数据，删去
data = data.drop(data[data['rent_area'] < 5].index)

# %%
# 7. rent_price_unit
data['rent_price_unit'].unique()
# Out:
# array(['元/月'], dtype=object)

# %%
# 租金都是以“元/月”计算的，所以这一列没用了，可以删了
data = data.drop(columns='rent_price_unit')

# %%
# 8. rent_price_listing
data[data['rent_price_listing'].str.contains('-')].sample(3)
# Out:
#       bathroom_num bedroom_num bizcircle_name city dist distance  \
# 82683            1           1             西丽   深圳  南山区     None
# 92117            1           2             民治   深圳  龙华区     None
# 66053            1           1            金沙洲   广州   白云     None
#
#       frame_orientation hall_num         house_tag  \
# 82683               南 西        0  独栋公寓 近地铁 押一付一 新上
# 92117                东南        1       独栋公寓 月租 近地铁
# 66053                东南        1              独栋公寓
#
#                          house_title   latitude  layout   longitude  \
# 82683  集悦城@红花岭 大学城红花岭店14栋 精装阳台A户型 开间   22.58299  1室0厅1卫  113.975165
# 92117             品客公寓 青创城店 两房一厅 二居+  22.620215  2室1厅1卫  114.045768
# 66053                   万科泊寓 横沙店 平层C  23.156453  1室1厅1卫  113.205889
#
#                                                    m_url  rent_area  \
# 82683  https://m.lianjia.com/chuzu/sz/apartment/layou...       24.0
# 92117  https://m.lianjia.com/chuzu/sz/apartment/layou...       75.0
# 66053  https://m.lianjia.com/chuzu/gz/apartment/layou...       30.0
#
#       rent_price_listing resblock_name type
# 82683          2412-2565                 整租
# 92117          4200-4800                 整租
# 66053          1450-1480                 整租

# %%
# 价格是有区间的，需要按照处理rent_area一样的方法处理
data['rent_price_listing'] = data['rent_price_listing'].apply(get_aver)

# %%
# 数据类型转换
for col in ['bathroom_num', 'bedroom_num', 'hall_num', 'rent_price_listing']:
    data[col] = data[col].astype(int)

# %%
# 'distance', 'latitude', 'longitude'因为有None，需另外处理
def dw_None_dis(data):
    if data is None:
        return np.nan
    else:
        return int(data)
    

def dw_None_latlon(data):
    if data is None or data == '':
        return np.nan
    else:
        return float(data)            


data['distance'] = data['distance'].apply(dw_None_dis)
data['latitude'] = data['latitude'].apply(dw_None_latlon)
data['longitude'] = data['longitude'].apply(dw_None_latlon)

# %%
# 查看数据概况
data.sample(5)
# Out:
#         bathroom_num  bedroom_num bizcircle_name city dist  distance  \
# 8526               2            3             鲁谷   北京  石景山     636.0
# 72321              1            1            新塘北   广州   增城       NaN
# 19208              1            2           中山公园   上海   长宁    1067.0
# 8634               2            2             果园   北京   通州     366.0
# 103271             1            1             张江   上海   浦东     652.0
#
#        frame_orientation  hall_num                 house_tag  \
# 8526                  东南         2          近地铁 精装 集中供暖 双卫生间
# 72321               东南 南         1                独栋公寓 月租 新上
# 19208                  南         1                  近地铁 随时看房
# 8634                 南 北         2  近地铁 精装 集中供暖 双卫生间 新上 随时看房
# 103271                 东         1                       近地铁
#
#                         house_title   latitude  layout   longitude  \
# 8526          整租 · 远洋山水 3室2厅 11500元  39.906426  3室2厅2卫  116.247008
# 72321          云栈物业 增城一期 一房一厅I免租一个月  23.192006  1室1厅1卫  113.868140
# 19208    精装修双南两房 高楼层 采光好 生活配套齐 拎包入住  31.218774  2室1厅1卫  121.435376
# 8634        整租 · 新华联家园北区 2室2厅 5600元  39.899289  2室2厅2卫  116.648674
# 103271  距离广兰路地铁站2号口500米小区设施配套齐全随时看房  31.216384  1室1厅1卫  121.633162
#
#                                                     m_url  rent_area  \
# 8526    https://m.lianjia.com/chuzu/bj/zufang/BJ216303...      124.0
# 72321   https://m.lianjia.com/chuzu/gz/apartment/layou...       24.0
# 19208   https://m.lianjia.com/chuzu/sh/zufang/SH218971...       48.0
# 8634    https://m.lianjia.com/chuzu/bj/zufang/BJ219405...      102.0
# 103271  https://m.lianjia.com/chuzu/sh/zufang/SH211662...       53.0
#
#         rent_price_listing resblock_name type
# 8526                 11500          远洋山水   整租
# 72321                  800                 整租
# 19208                 7000        昭化路60弄   整租
# 8634                  5600       新华联家园北区   整租
# 103271                5000          展想悦廷   整租

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105258 entries, 0 to 105261
# Data columns (total 18 columns):
# bathroom_num          105258 non-null int64
# bedroom_num           105258 non-null int64
# bizcircle_name        105258 non-null object
# city                  105258 non-null object
# dist                  105258 non-null object
# distance              57934 non-null float64
# frame_orientation     105258 non-null object
# hall_num              105258 non-null int64
# house_tag             85087 non-null object
# house_title           105258 non-null object
# latitude              104834 non-null float64
# layout                105258 non-null object
# longitude             104834 non-null float64
# m_url                 105258 non-null object
# rent_area             105258 non-null float64
# rent_price_listing    105258 non-null int64
# resblock_name         105258 non-null object
# type                  105258 non-null object
# dtypes: float64(4), int64(4), object(10)
# memory usage: 15.3+ MB

# %%
data.to_csv('data_clean.csv', index=False)

# %% [markdown]
# 问题：
# 1. 各城市的租房分布怎么样？
# 2. 城市各区域的房价分布怎么样？
# 2. 距离地铁口远近有什么关系？
# 3. 房屋大小对价格的影响如何？
# 4. 租个人房源好还是公寓好？
# 5. 精装和简装对房子价格的影响
# 6. 北方集中供暖对价格的影响
# 7. 北上广深租房时都看重什么？

# %% [markdown]
# ### 1. 各城市的租房分布怎么样？

# %%
def get_city_zf_loc(city, city_short, col=['longitude', 'latitude', 'dist'], data=data):
    file_name = 'data_' + city_short + '_latlon.csv'
    data_latlon = data.loc[data['city']==city, col].dropna(subset=['latitude', 'longitude'])
    data_latlon['longitude'] = data_latlon['longitude'].astype(str)
    data_latlon['latitude'] = data_latlon['latitude'].astype(str)
    data_latlon['latlon'] = data_latlon['longitude'].str.cat(data_latlon['latitude'], sep=',')
    data_latlon.to_csv(file_name, index=False)
    print(city+'的数据一共有{}条'.format(data_latlon.shape[0]))

# %%
get_city_zf_loc('北京', 'bj', ['longitude','latitude', 'dist'])
get_city_zf_loc('上海', 'sh', ['longitude','latitude', 'dist'])
get_city_zf_loc('广州', 'gz', ['longitude','latitude', 'dist'])
get_city_zf_loc('深圳', 'sz', ['longitude','latitude', 'dist'])
# Out:
# 北京的数据一共有18012条
# 上海的数据一共有27311条
# 广州的数据一共有39457条
# 深圳的数据一共有20054条

# %%
fig = plt.figure(dpi=300)
data.dropna(subset=['latitude', 'longitude'])[data['city']=='北京']['dist'].value_counts(ascending=True).plot.barh()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
fig = plt.figure(dpi=300)
data.dropna(subset=['latitude', 'longitude'])[data['city']=='上海']['dist'].value_counts(ascending=True).plot.barh()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
fig = plt.figure(dpi=300)
data.dropna(subset=['latitude', 'longitude'])[data['city']=='广州']['dist'].value_counts(ascending=True).plot.barh()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
fig = plt.figure(dpi=300)
data.dropna(subset=['latitude', 'longitude'])[data['city']=='深圳']['dist'].value_counts(ascending=True).plot.barh()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# ### 2. 城市各区域的房价分布怎么样？

# %%
data['aver_price'] = np.round(data['rent_price_listing'] / data['rent_area'], 1)

# %%
g = sns.FacetGrid(data, row="city", height=4, aspect=2)
g = g.map(sns.kdeplot, "aver_price")

# %%
# 由于平均租金基本上都集中在250元/平米/月以内，所以选取这部分数据绘制热力图
def get_city_zf_aver_price(city, city_short, col=['longitude', 'latitude', 'aver_price'], data=data):
    file_name = 'data_' + city_short + '_aver_price.csv'
    data_latlon = data.loc[(data['city']==city)&(data['aver_price']<=250), col].dropna(subset=['latitude', 'longitude'])
    data_latlon['longitude'] = data_latlon['longitude'].astype(str)
    data_latlon['latitude'] = data_latlon['latitude'].astype(str)
    data_latlon['latlon'] = data_latlon['longitude'].str.cat(data_latlon['latitude'], sep=',')
    data_latlon.to_csv(file_name, index=False)
    print(city+'的数据一共有{}条'.format(data_latlon.shape[0]))

# %%
get_city_zf_aver_price('北京', 'bj')
get_city_zf_aver_price('上海', 'sh')
get_city_zf_aver_price('广州', 'gz')
get_city_zf_aver_price('深圳', 'sz')
# Out:
# 北京的数据一共有17868条
# 上海的数据一共有27161条
# 广州的数据一共有39333条
# 深圳的数据一共有19655条

# %%
# 各城市租金Top10的商圈
bc_top10 = data.groupby(['city', 'bizcircle_name'])['aver_price'].mean().nlargest(50).reset_index()['city'].value_counts()

# %%
from pyecharts import Bar

bar = Bar("每平米平均租金前50的北上广深商圈数量", width=400)
bar.add("", bc_top10.index, bc_top10.values, is_stack=True,
       xaxis_label_textsize=16, yaxis_label_textsize=16, is_label_show=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="286a367d389b44cd94308d49e4d0980b" style="width:400px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_286a367d389b44cd94308d49e4d0980b = echarts.init(document.getElementById('286a367d389b44cd94308d49e4d0980b'), null, {renderer: 'canvas'});
# var option_286a367d389b44cd94308d49e4d0980b = {
#     "title": [
#         {
#             "text": "\u6bcf\u5e73\u7c73\u5e73\u5747\u79df\u91d1\u524d50\u7684\u5317\u4e0a\u5e7f\u6df1\u5546\u5708\u6570\u91cf",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 5985107,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "",
#             "data": [
#                 27.0,
#                 11.0,
#                 10.0,
#                 2.0
#             ],
#             "stack": "stack_5985107",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5985107
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "xAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 16,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "data": [
#                 "\u5317\u4eac",
#                 "\u4e0a\u6d77",
#                 "\u6df1\u5733",
#                 "\u5e7f\u5dde"
#             ],
#             "type": "category"
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "interval": "auto",
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 16,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "splitLine": {
#                 "show": true
#             },
#             "type": "value"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_286a367d389b44cd94308d49e4d0980b.setOption(option_286a367d389b44cd94308d49e4d0980b);
#
#     });
# </script>

# %%
def get_top10_bc(city, data=data):
    top10_bc = data[(data['city']==city)&(data['bizcircle_name']!='')].groupby('bizcircle_name')['aver_price'].mean().nlargest(10)
    bar = Bar(city+"市每平米平均租金Top10的商圈", width=600)
    bar.add("", top10_bc.index, np.round(top10_bc.values, 0), is_stack=True,
       xaxis_label_textsize=16, yaxis_label_textsize=16, xaxis_rotate=30, is_label_show=True)
    return bar

# %%
# 北京每平米平均租金Top10的商圈
get_top10_bc('北京')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="b4e90fbc13c84e7491f6d01c560ca706" style="width:600px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_b4e90fbc13c84e7491f6d01c560ca706 = echarts.init(document.getElementById('b4e90fbc13c84e7491f6d01c560ca706'), null, {renderer: 'canvas'});
# var option_b4e90fbc13c84e7491f6d01c560ca706 = {
#     "title": [
#         {
#             "text": "\u5317\u4eac\u5e02\u6bcf\u5e73\u7c73\u5e73\u5747\u79df\u91d1Top10\u7684\u5546\u5708",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 6708506,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "",
#             "data": [
#                 239.0,
#                 223.0,
#                 214.0,
#                 206.0,
#                 198.0,
#                 198.0,
#                 173.0,
#                 172.0,
#                 170.0,
#                 164.0
#             ],
#             "stack": "stack_6708506",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 6708506
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "xAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 30,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 16,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "data": [
#                 "\u4e1c\u5355",
#                 "\u4e1c\u56db",
#                 "\u5730\u5b89\u95e8",
#                 "\u4e2d\u5173\u6751",
#                 "\u91d1\u878d\u8857",
#                 "\u4ea4\u9053\u53e3",
#                 "\u5ba3\u6b66\u95e8",
#                 "\u4e1c\u5927\u6865",
#                 "\u897f\u56db",
#                 "\u897f\u5355"
#             ],
#             "type": "category"
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "interval": "auto",
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 16,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "splitLine": {
#                 "show": true
#             },
#             "type": "value"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_b4e90fbc13c84e7491f6d01c560ca706.setOption(option_b4e90fbc13c84e7491f6d01c560ca706);
#
#     });
# </script>

# %%
get_top10_bc('上海')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="68b38958fd124603bb778b7c433d5738" style="width:600px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_68b38958fd124603bb778b7c433d5738 = echarts.init(document.getElementById('68b38958fd124603bb778b7c433d5738'), null, {renderer: 'canvas'});
# var option_68b38958fd124603bb778b7c433d5738 = {
#     "title": [
#         {
#             "text": "\u4e0a\u6d77\u5e02\u6bcf\u5e73\u7c73\u5e73\u5747\u79df\u91d1Top10\u7684\u5546\u5708",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 2329374,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "",
#             "data": [
#                 213.0,
#                 200.0,
#                 197.0,
#                 177.0,
#                 172.0,
#                 165.0,
#                 165.0,
#                 157.0,
#                 156.0,
#                 154.0
#             ],
#             "stack": "stack_2329374",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 2329374
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "xAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 30,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 16,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "data": [
#                 "\u65b0\u5929\u5730",
#                 "\u6dee\u6d77\u4e2d\u8def",
#                 "\u8861\u5c71\u8def",
#                 "\u9759\u5b89\u5bfa",
#                 "\u5357\u4eac\u897f\u8def",
#                 "\u5efa\u56fd\u897f\u8def",
#                 "\u9547\u5b81\u8def",
#                 "\u5357\u4eac\u4e1c\u8def",
#                 "\u9ec4\u6d66\u6ee8\u6c5f",
#                 "\u53e4\u5317"
#             ],
#             "type": "category"
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "interval": "auto",
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 16,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "splitLine": {
#                 "show": true
#             },
#             "type": "value"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_68b38958fd124603bb778b7c433d5738.setOption(option_68b38958fd124603bb778b7c433d5738);
#
#     });
# </script>

# %%
get_top10_bc('广州')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="fc914effe3494f3da9eb13698fa0259c" style="width:600px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_fc914effe3494f3da9eb13698fa0259c = echarts.init(document.getElementById('fc914effe3494f3da9eb13698fa0259c'), null, {renderer: 'canvas'});
# var option_fc914effe3494f3da9eb13698fa0259c = {
#     "title": [
#         {
#             "text": "\u5e7f\u5dde\u5e02\u6bcf\u5e73\u7c73\u5e73\u5747\u79df\u91d1Top10\u7684\u5546\u5708",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 5053905,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "",
#             "data": [
#                 181.0,
#                 150.0,
#                 144.0,
#                 138.0,
#                 125.0,
#                 116.0,
#                 110.0,
#                 108.0,
#                 104.0,
#                 101.0
#             ],
#             "stack": "stack_5053905",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5053905
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "xAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 30,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 16,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "data": [
#                 "\u4e8c\u6c99\u5c9b",
#                 "\u89e3\u653e\u5317",
#                 "\u4eba\u6c11\u5317",
#                 "\u73e0\u6c5f\u65b0\u57ce\u4e2d",
#                 "\u73e0\u6c5f\u65b0\u57ce\u4e1c",
#                 "\u73e0\u6c5f\u65b0\u57ce\u897f",
#                 "\u6587\u51b2",
#                 "\u5317\u4eac\u8def",
#                 "\u6768\u7b95",
#                 "\u5929\u6cb3\u5357"
#             ],
#             "type": "category"
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "interval": "auto",
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 16,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "splitLine": {
#                 "show": true
#             },
#             "type": "value"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_fc914effe3494f3da9eb13698fa0259c.setOption(option_fc914effe3494f3da9eb13698fa0259c);
#
#     });
# </script>

# %%
get_top10_bc('深圳')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="968b7b119bfa409aa9739cdf6a972d04" style="width:600px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_968b7b119bfa409aa9739cdf6a972d04 = echarts.init(document.getElementById('968b7b119bfa409aa9739cdf6a972d04'), null, {renderer: 'canvas'});
# var option_968b7b119bfa409aa9739cdf6a972d04 = {
#     "title": [
#         {
#             "text": "\u6df1\u5733\u5e02\u6bcf\u5e73\u7c73\u5e73\u5747\u79df\u91d1Top10\u7684\u5546\u5708",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 6837327,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "",
#             "data": [
#                 194.0,
#                 186.0,
#                 177.0,
#                 167.0,
#                 166.0,
#                 160.0,
#                 154.0,
#                 154.0,
#                 152.0,
#                 151.0
#             ],
#             "stack": "stack_6837327",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 6837327
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "xAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 30,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 16,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "data": [
#                 "\u6df1\u5733\u6e7e",
#                 "\u798f\u7530\u4e2d\u5fc3",
#                 "\u9999\u871c\u6e56",
#                 "\u7ea2\u6811\u6e7e",
#                 "\u6885\u6797",
#                 "\u65b0\u6d32",
#                 "\u666f\u7530",
#                 "\u540e\u6d77",
#                 "\u79d1\u6280\u56ed",
#                 "\u4e0a\u4e0b\u6c99"
#             ],
#             "type": "category"
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "interval": "auto",
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 16,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "splitLine": {
#                 "show": true
#             },
#             "type": "value"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_968b7b119bfa409aa9739cdf6a972d04.setOption(option_968b7b119bfa409aa9739cdf6a972d04);
#
#     });
# </script>

# %% [markdown]
# ### 3. 距离地铁口远近有什么关系？

# %%
from scipy import stats

# %%
def distance_price_relation(city, data=data):
    g = sns.jointplot(x="distance", 
                  y="aver_price", 
                  data=data[(data['city']==city)&
                            (data['aver_price']<=350)].dropna(subset=['distance']), 
                  kind="reg",
                 stat_func=stats.pearsonr)
    g.fig.set_dpi(100)
    g.ax_joint.set_xlabel('最近地铁距离', fontweight='bold')
    g.ax_joint.set_ylabel('每平米租金', fontweight='bold')
    return g

# %%
distance_price_relation('北京')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
distance_price_relation('上海')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
distance_price_relation('广州')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
distance_price_relation('深圳')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
bins = [100*i for i in range(13)]
data['bin'] = pd.cut(data.dropna(subset=['distance'])['distance'], bins)

# %%
bin_bj = data[data['city']=='北京'].groupby('bin')['aver_price'].mean()
bin_sh = data[data['city']=='上海'].groupby('bin')['aver_price'].mean()
bin_gz = data[data['city']=='广州'].groupby('bin')['aver_price'].mean()
bin_sz = data[data['city']=='深圳'].groupby('bin')['aver_price'].mean()

# %%
from pyecharts import Line


line = Line("距离地铁远近跟每平米租金均价的关系")
for city, bin_data in {'北京':bin_bj, '上海':bin_sh, '广州':bin_gz, '深圳':bin_sz}.items():
    line.add(city, bin_data.index, bin_data.values,
            legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
             xaxis_rotate=20, yaxis_min=8, legend_top=30)
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="144f00673ec641dfa111d43380b241fa" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_144f00673ec641dfa111d43380b241fa = echarts.init(document.getElementById('144f00673ec641dfa111d43380b241fa'), null, {renderer: 'canvas'});
# var option_144f00673ec641dfa111d43380b241fa = {
#     "title": [
#         {
#             "text": "\u8ddd\u79bb\u5730\u94c1\u8fdc\u8fd1\u8ddf\u6bcf\u5e73\u7c73\u79df\u91d1\u5747\u4ef7\u7684\u5173\u7cfb",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 7630889,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5317\u4eac",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "stack": "",
#             "showSymbol": true,
#             "data": [
#                 111.28428745432406,
#                 120.34476806903969,
#                 111.10963855421669,
#                 113.57302052785923,
#                 116.71517352703796,
#                 107.09462121212113,
#                 120.31165540540528,
#                 111.57050147492622,
#                 109.67596048298562,
#                 97.20996309963094,
#                 99.44956843403197,
#                 95.32921646746351
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": null
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0,
#                 "color": null
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 7630889
#         },
#         {
#             "type": "line",
#             "name": "\u4e0a\u6d77",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "stack": "",
#             "showSymbol": true,
#             "data": [
#                 112.06108726752493,
#                 108.38790915163658,
#                 111.08650990099012,
#                 109.77908997955008,
#                 106.08529878371219,
#                 109.21274089935761,
#                 108.16108970831034,
#                 104.53700265251985,
#                 97.88409415121262,
#                 91.24294117647072,
#                 86.75922920892488,
#                 76.16707152496632
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": null
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0,
#                 "color": null
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 7630889
#         },
#         {
#             "type": "line",
#             "name": "\u5e7f\u5dde",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "stack": "",
#             "showSymbol": true,
#             "data": [
#                 67.31258223684218,
#                 71.41378178835113,
#                 73.99070294784588,
#                 74.71897297297289,
#                 72.39218410768557,
#                 69.52999478351586,
#                 68.1650139664804,
#                 69.24672382118794,
#                 67.40192887281492,
#                 54.952777777777776,
#                 58.151714677640584,
#                 57.544035947712544
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": null
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0,
#                 "color": null
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 7630889
#         },
#         {
#             "type": "line",
#             "name": "\u6df1\u5733",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "stack": "",
#             "showSymbol": true,
#             "data": [
#                 121.41168969181713,
#                 133.2797268907561,
#                 132.88795589482606,
#                 134.609628975265,
#                 116.97755868544606,
#                 124.9936234817814,
#                 124.02877192982464,
#                 116.09665071770334,
#                 120.57692307692301,
#                 117.03485915492956,
#                 97.6586288416075

# %%
134.6-117
# Out:
# 17.599999999999994

# %% [markdown]
# ### 4. 房屋大小对每平米租金的影响如何？

# %%
def area_price_relation(city, data=data):
    fig = plt.figure(dpi=100)
    g = sns.lineplot(x="rent_area",
                     y="aver_price",
                     data=data[(data['city']==city)&(data['rent_area']<150)],
                     ci=None)
    g.set_xlabel('面积', fontweight='bold')
    g.set_ylabel('每平米均价', fontweight='bold')
    return g

# %%
area_price_relation('北京')

# %%
area_price_relation('上海')

# %%
area_price_relation('广州')

# %%
area_price_relation('深圳')

# %%
# 根据house_title和house_tag再造一个字段：is_dep，也就是“是否是公寓”
data['is_dep'] = (data['house_title'].str.contains('公寓') + data['house_tag'].str.contains('公寓')) > 0

# %%
# 每个城市房源的公寓占比
for city in ['北京', '上海', '广州', '深圳']:
    print(city+'的公寓占总房源量比重为:{}%。'.format(
        np.round(data[data['city']==city]['is_dep'].mean()*100, 2)))
# Out:
# 北京的公寓占总房源量比重为:1.79%。
# 上海的公寓占总房源量比重为:3.7%。
# 广州的公寓占总房源量比重为:20.01%。
# 深圳的公寓占总房源量比重为:50.53%。

# %%
data[(data['city']=='广州')&
    (data['rent_area']>0)&
    (data['rent_area']<60)&
    (data['aver_price']>100)]['is_dep'].mean()
# Out:
# 0.31666666666666665

# %% [markdown]
# ### 5. 租个人房源好还是公寓好？

# %%
is_dep = data[(data['city'].isin(['广州','深圳']))&
             (data['is_dep']==1)].groupby('city')['aver_price'].mean()
not_dep = data[(data['city'].isin(['广州','深圳']))&
             (data['is_dep']==0)].groupby('city')['aver_price'].mean()

# %%
bar = Bar("个人房源和公寓的每平米租金差别", width=600)
bar.add("个人房源", not_dep.index, np.round(not_dep.values, 0), 
        legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
        xaxis_rotate=20, yaxis_min=8, legend_top=30, is_label_show=True)
bar.add("公寓", is_dep.index, np.round(is_dep.values, 0),
       legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
        xaxis_rotate=20, yaxis_min=8, legend_top=30, is_label_show=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="cf300f5bdb3c427f8cc8af11f8d9457e" style="width:600px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_cf300f5bdb3c427f8cc8af11f8d9457e = echarts.init(document.getElementById('cf300f5bdb3c427f8cc8af11f8d9457e'), null, {renderer: 'canvas'});
# var option_cf300f5bdb3c427f8cc8af11f8d9457e = {
#     "title": [
#         {
#             "text": "\u4e2a\u4eba\u623f\u6e90\u548c\u516c\u5bd3\u7684\u6bcf\u5e73\u7c73\u79df\u91d1\u5dee\u522b",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 7944090,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4e2a\u4eba\u623f\u6e90",
#             "data": [
#                 54.0,
#                 100.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 7944090
#         },
#         {
#             "type": "bar",
#             "name": "\u516c\u5bd3",
#             "data": [
#                 66.0,
#                 102.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 7944090
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e2a\u4eba\u623f\u6e90",
#                 "\u516c\u5bd3"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": 30,
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 18,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "xAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 20,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 14,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "data": [
#                 "\u5e7f\u5dde",
#                 "\u6df1\u5733"
#             ],
#             "type": "category"
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "interval": "auto",
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 18,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": 8,
#             "max": null,
#             "splitLine": {
#                 "show": true
#             },
#             "type": "value"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_cf300f5bdb3c427f8cc8af11f8d9457e.setOption(option_cf300f5bdb3c427f8cc8af11f8d9457e);
#
#     });
# </script>

# %% [markdown]
# ### 5. 精装和简装对房子价格的影响

# %%
data['decorated'] = data[data['house_tag'].notna()]['house_tag'].str.contains('精装')

# %%
decorated = data[data['decorated']==1].groupby('city')['aver_price'].mean()

# %%
not_decorated = data[data['decorated']==0].groupby('city')['aver_price'].mean()

# %%
bar = Bar("各城市精装和简装的每平米租金差别", width=600)
bar.add("精装(刷过墙)", decorated.index, np.round(decorated.values, 0), 
        legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
        xaxis_rotate=20, yaxis_min=8, legend_top=30, is_label_show=True)
bar.add("简装(破房子)", not_decorated.index, np.round(not_decorated.values, 0),
       legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
        xaxis_rotate=20, yaxis_min=8, legend_top=30, is_label_show=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="6e5b32a358914383b801a8a4a410326a" style="width:600px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_6e5b32a358914383b801a8a4a410326a = echarts.init(document.getElementById('6e5b32a358914383b801a8a4a410326a'), null, {renderer: 'canvas'});
# var option_6e5b32a358914383b801a8a4a410326a = {
#     "title": [
#         {
#             "text": "\u5404\u57ce\u5e02\u7cbe\u88c5\u548c\u7b80\u88c5\u7684\u6bcf\u5e73\u7c73\u79df\u91d1\u5dee\u522b",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 7366116,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7cbe\u88c5(\u5237\u8fc7\u5899)",
#             "data": [
#                 119.0,
#                 108.0,
#                 93.0,
#                 137.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 7366116
#         },
#         {
#             "type": "bar",
#             "name": "\u7b80\u88c5(\u7834\u623f\u5b50)",
#             "data": [
#                 91.0,
#                 92.0,
#                 58.0,
#                 91.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 7366116
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7cbe\u88c5(\u5237\u8fc7\u5899)",
#                 "\u7b80\u88c5(\u7834\u623f\u5b50)"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": 30,
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 18,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "xAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 20,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 14,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "data": [
#                 "\u4e0a\u6d77",
#                 "\u5317\u4eac",
#                 "\u5e7f\u5dde",
#                 "\u6df1\u5733"
#             ],
#             "type": "category"
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "interval": "auto",
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 18,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": 8,
#             "max": null,
#             "splitLine": {
#                 "show": true
#             },
#             "type": "value"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_6e5b32a358914383b801a8a4a410326a.setOption(option_6e5b32a358914383b801a8a4a410326a);
#
#     });
# </script>

# %%
is_dec_dep = data[(data['decorated']==1)&
                  (data['is_dep']==1)&
                 (data['city'].isin(['广州', '深圳']))].groupby('city')['aver_price'].mean()

# %%
is_dec_not_dep = data[(data['decorated']==1)&
                      (data['is_dep']==0)&
                     (data['city'].isin(['广州', '深圳']))].groupby('city')['aver_price'].mean()

# %%
not_dec_dep = data[(data['decorated']==0)&
                   (data['is_dep']==0)&
                  (data['city'].isin(['广州', '深圳']))].groupby('city')['aver_price'].mean()

# %%
bar = Bar("各城市装修和房源类型的每平米租金差别", width=600)
bar.add("精装公寓", is_dec_dep.index, np.round(is_dec_dep.values, 0), 
        legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
        xaxis_rotate=20, yaxis_min=8, legend_top=30, is_label_show=True)
bar.add("精装个人房源", is_dec_not_dep.index, np.round(is_dec_not_dep.values, 0),
       legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
        xaxis_rotate=20, yaxis_min=8, legend_top=30, is_label_show=True)
bar.add("简装个人房源", not_dec_dep.index, np.round(not_dec_dep.values, 0),
       legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
        xaxis_rotate=20, yaxis_min=8, legend_top=30, is_label_show=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="a09f9d42fd174b2ea8c449f25c0a2763" style="width:600px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_a09f9d42fd174b2ea8c449f25c0a2763 = echarts.init(document.getElementById('a09f9d42fd174b2ea8c449f25c0a2763'), null, {renderer: 'canvas'});
# var option_a09f9d42fd174b2ea8c449f25c0a2763 = {
#     "title": [
#         {
#             "text": "\u5404\u57ce\u5e02\u88c5\u4fee\u548c\u623f\u6e90\u7c7b\u578b\u7684\u6bcf\u5e73\u7c73\u79df\u91d1\u5dee\u522b",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 5269130,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7cbe\u88c5\u516c\u5bd3",
#             "data": [
#                 137.0,
#                 157.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5269130
#         },
#         {
#             "type": "bar",
#             "name": "\u7cbe\u88c5\u4e2a\u4eba\u623f\u6e90",
#             "data": [
#                 60.0,
#                 111.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5269130
#         },
#         {
#             "type": "bar",
#             "name": "\u7b80\u88c5\u4e2a\u4eba\u623f\u6e90",
#             "data": [
#                 59.0,
#                 101.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5269130
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7cbe\u88c5\u516c\u5bd3",
#                 "\u7cbe\u88c5\u4e2a\u4eba\u623f\u6e90",
#                 "\u7b80\u88c5\u4e2a\u4eba\u623f\u6e90"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": 30,
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 18,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "xAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 20,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 14,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "data": [
#                 "\u5e7f\u5dde",
#                 "\u6df1\u5733"
#             ],
#             "type": "category"
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "interval": "auto",
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 18,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": 8,
#             "max": null,
#             "splitLine": {
#                 "show": true
#             },
#             "type": "value"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_a09f9d42fd174b2ea8c449f25c0a2763.setOption(option_a09f9d42fd174b2ea8c449f25c0a2763);
#
#     });
# </script>

# %% [markdown]
# ### 7. 北方集中供暖对价格的影响

# %%
data['ct_heating'] = data['house_tag'].str.contains('集中供暖')

# %%
data[data['city']=='北京'].groupby('ct_heating')['aver_price'].mean()
# Out:
# ct_heating
# False     91.638957
# True     100.183416
# Name: aver_price, dtype: float64

# %% [markdown]
# ### 8. 各城市房屋租售比

# %%
zs_ratio = [57036, 62779, 32039, 56758]/(data.groupby('city')['rent_price_listing'].sum()/data.groupby('city')['rent_area'].sum())/12

# %%
bar = Bar("各城市房屋租售比(租多少年可以在该城市买下一套房)", width=450)
bar.add("", zs_ratio.index, np.round(zs_ratio.values, 0), 
        legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
        xaxis_rotate=20, yaxis_min=8, legend_top=30, is_label_show=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="a0b98dae167f4949a2a8d3a319887340" style="width:450px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_a0b98dae167f4949a2a8d3a319887340 = echarts.init(document.getElementById('a0b98dae167f4949a2a8d3a319887340'), null, {renderer: 'canvas'});
# var option_a0b98dae167f4949a2a8d3a319887340 = {
#     "title": [
#         {
#             "text": "\u5404\u57ce\u5e02\u623f\u5c4b\u79df\u552e\u6bd4(\u79df\u591a\u5c11\u5e74\u53ef\u4ee5\u5728\u8be5\u57ce\u5e02\u4e70\u4e0b\u4e00\u5957\u623f)",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 308225,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "",
#             "data": [
#                 53.0,
#                 53.0,
#                 51.0,
#                 48.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 308225
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": 30,
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 18,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "xAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 20,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 14,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "data": [
#                 "\u4e0a\u6d77",
#                 "\u5317\u4eac",
#                 "\u5e7f\u5dde",
#                 "\u6df1\u5733"
#             ],
#             "type": "category"
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "interval": "auto",
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 18,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": 8,
#             "max": null,
#             "splitLine": {
#                 "show": true
#             },
#             "type": "value"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_a0b98dae167f4949a2a8d3a319887340.setOption(option_a0b98dae167f4949a2a8d3a319887340);
#
#     });
# </script>

# %% [markdown]
# ### 9. 北上广深租房时都看重什么？

# %%
def layout_top3(city, data):
    layout_data = data[data['city']==city]['layout'].value_counts().nlargest(3)
    bar = Bar(city+"最受欢迎的户型", width=600)
    bar.add("", layout_data.index, layout_data.values, 
        legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
        xaxis_rotate=20, yaxis_min=8, legend_top=30, is_label_show=True)
    return bar

# %%
layout_top3('北京', data)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="ccc25a33c2364fa7b9f07aa146e0ca71" style="width:600px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_ccc25a33c2364fa7b9f07aa146e0ca71 = echarts.init(document.getElementById('ccc25a33c2364fa7b9f07aa146e0ca71'), null, {renderer: 'canvas'});
# var option_ccc25a33c2364fa7b9f07aa146e0ca71 = {
#     "title": [
#         {
#             "text": "\u5317\u4eac\u6700\u53d7\u6b22\u8fce\u7684\u6237\u578b",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 7154765,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "",
#             "data": [
#                 6603.0,
#                 2763.0,
#                 1366.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 7154765
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": 30,
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 18,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "xAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 20,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 14,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "data": [
#                 "2\u5ba41\u53851\u536b",
#                 "1\u5ba41\u53851\u536b",
#                 "3\u5ba41\u53851\u536b"
#             ],
#             "type": "category"
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "interval": "auto",
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 18,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": 8,
#             "max": null,
#             "splitLine": {
#                 "show": true
#             },
#             "type": "value"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_ccc25a33c2364fa7b9f07aa146e0ca71.setOption(option_ccc25a33c2364fa7b9f07aa146e0ca71);
#
#     });
# </script>

# %%
layout_top3('上海', data)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="d4a4c85db7aa4ce198c6edc43fa3e1ad" style="width:600px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_d4a4c85db7aa4ce198c6edc43fa3e1ad = echarts.init(document.getElementById('d4a4c85db7aa4ce198c6edc43fa3e1ad'), null, {renderer: 'canvas'});
# var option_d4a4c85db7aa4ce198c6edc43fa3e1ad = {
#     "title": [
#         {
#             "text": "\u4e0a\u6d77\u6700\u53d7\u6b22\u8fce\u7684\u6237\u578b",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 2539032,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "",
#             "data": [
#                 5154.0,
#                 4568.0,
#                 4188.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 2539032
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": 30,
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 18,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "xAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 20,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 14,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "data": [
#                 "2\u5ba41\u53851\u536b",
#                 "1\u5ba41\u53851\u536b",
#                 "2\u5ba42\u53851\u536b"
#             ],
#             "type": "category"
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "interval": "auto",
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 18,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": 8,
#             "max": null,
#             "splitLine": {
#                 "show": true
#             },
#             "type": "value"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_d4a4c85db7aa4ce198c6edc43fa3e1ad.setOption(option_d4a4c85db7aa4ce198c6edc43fa3e1ad);
#
#     });
# </script>

# %%
layout_top3('广州', data)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="213b5981575c4fcc903fcde47b9d879b" style="width:600px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_213b5981575c4fcc903fcde47b9d879b = echarts.init(document.getElementById('213b5981575c4fcc903fcde47b9d879b'), null, {renderer: 'canvas'});
# var option_213b5981575c4fcc903fcde47b9d879b = {
#     "title": [
#         {
#             "text": "\u5e7f\u5dde\u6700\u53d7\u6b22\u8fce\u7684\u6237\u578b",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 1618984,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "",
#             "data": [
#                 8004.0,
#                 6872.0,
#                 4489.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 1618984
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": 30,
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 18,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "xAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 20,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 14,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "data": [
#                 "2\u5ba41\u53851\u536b",
#                 "1\u5ba41\u53851\u536b",
#                 "3\u5ba42\u53852\u536b"
#             ],
#             "type": "category"
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "interval": "auto",
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 18,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": 8,
#             "max": null,
#             "splitLine": {
#                 "show": true
#             },
#             "type": "value"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_213b5981575c4fcc903fcde47b9d879b.setOption(option_213b5981575c4fcc903fcde47b9d879b);
#
#     });
# </script>

# %%
layout_top3('深圳', data)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="897eaee14b1348198c8d534ea0c16030" style="width:600px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_897eaee14b1348198c8d534ea0c16030 = echarts.init(document.getElementById('897eaee14b1348198c8d534ea0c16030'), null, {renderer: 'canvas'});
# var option_897eaee14b1348198c8d534ea0c16030 = {
#     "title": [
#         {
#             "text": "\u6df1\u5733\u6700\u53d7\u6b22\u8fce\u7684\u6237\u578b",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 4070627,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "",
#             "data": [
#                 5301.0,
#                 3541.0,
#                 2276.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 4070627
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": 30,
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 18,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "xAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 20,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 14,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "data": [
#                 "1\u5ba40\u53851\u536b",
#                 "1\u5ba41\u53851\u536b",
#                 "2\u5ba41\u53851\u536b"
#             ],
#             "type": "category"
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "interval": "auto",
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 18,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": 8,
#             "max": null,
#             "splitLine": {
#                 "show": true
#             },
#             "type": "value"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_897eaee14b1348198c8d534ea0c16030.setOption(option_897eaee14b1348198c8d534ea0c16030);
#
#     });
# </script>

# %%
from pyecharts import WordCloud

# %%
bj_tag = []
for st in data[data['city']=='北京'].dropna(subset=['house_tag'])['house_tag']:
    bj_tag.extend(st.split(' '))

name, value = WordCloud.cast(Counter(bj_tag))
wordcloud = WordCloud(width=500, height=500)
wordcloud.add("", name, value, word_size_range=[20, 100])
wordcloud
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="50bb848f2c0d413a8962253a5b9bbbeb" style="width:500px;height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_50bb848f2c0d413a8962253a5b9bbbeb = echarts.init(document.getElementById('50bb848f2c0d413a8962253a5b9bbbeb'), null, {renderer: 'canvas'});
# var option_50bb848f2c0d413a8962253a5b9bbbeb = {
#     "title": [
#         {
#             "text": "",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 7095465,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u53cc\u536b\u751f\u95f4",
#                     "value": 2383,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(56,143,140)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u62bc\u4e00\u4ed8\u4e00",
#                     "value": 35,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(23,108,34)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b0\u4e0a",
#                     "value": 3985,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(103,9,61)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6708\u79df",
#                     "value": 111,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(34,60,3)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7cbe\u88c5",
#                     "value": 7484,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(90,109,84)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8fd1\u5730\u94c1",
#                     "value": 10426,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(27,110,36)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u968f\u65f6\u770b\u623f",
#                     "value": 9197,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(63,68,146)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u96c6\u4e2d\u4f9b\u6696",
#                     "value": 14574,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(48,79,93)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_50bb848f2c0d413a8962253a5b9bbbeb.setOption(option_50bb848f2c0d413a8962253a5b9bbbeb);
#
#     });
# </script>

# %%
sh_tag = []
for st in data[data['city']=='上海'].dropna(subset=['house_tag'])['house_tag']:
    sh_tag.extend(st.split(' '))

name, value = WordCloud.cast(Counter(sh_tag))
wordcloud = WordCloud(width=500, height=500)
wordcloud.add("", name, value, word_size_range=[20, 100])
wordcloud
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="ec5e57b7562341cb838672288e812cfc" style="width:500px;height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_ec5e57b7562341cb838672288e812cfc = echarts.init(document.getElementById('ec5e57b7562341cb838672288e812cfc'), null, {renderer: 'canvas'});
# var option_ec5e57b7562341cb838672288e812cfc = {
#     "title": [
#         {
#             "text": "",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 7754464,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u516c\u5bd3",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(110,92,87)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53cc\u536b\u751f\u95f4",
#                     "value": 1860,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(132,121,44)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u62bc\u4e00\u4ed8\u4e00",
#                     "value": 109,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(70,103,27)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b0\u4e0a",
#                     "value": 5067,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(71,116,143)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6708\u79df",
#                     "value": 23,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(92,123,135)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7cbe\u88c5",
#                     "value": 5255,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(16,10,124)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8fd1\u5730\u94c1",
#                     "value": 14773,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(135,61,16)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u968f\u65f6\u770b\u623f",
#                     "value": 6707,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(65,9,82)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_ec5e57b7562341cb838672288e812cfc.setOption(option_ec5e57b7562341cb838672288e812cfc);
#
#     });
# </script>

# %%
gz_tag = []
for st in data[data['city']=='广州'].dropna(subset=['house_tag'])['house_tag']:
    gz_tag.extend(st.split(' '))

name, value = WordCloud.cast(Counter(gz_tag))
wordcloud = WordCloud(width=500, height=500)
wordcloud.add("", name, value, word_size_range=[20, 100])
wordcloud
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="7fddfbac13524e9e8f6aac72ca27f8b9" style="width:500px;height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_7fddfbac13524e9e8f6aac72ca27f8b9 = echarts.init(document.getElementById('7fddfbac13524e9e8f6aac72ca27f8b9'), null, {renderer: 'canvas'});
# var option_7fddfbac13524e9e8f6aac72ca27f8b9 = {
#     "title": [
#         {
#             "text": "",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3735801,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u516c\u5bd3",
#                     "value": 1073,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(97,26,73)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53cc\u536b\u751f\u95f4",
#                     "value": 593,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(33,20,47)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u62bc\u4e00\u4ed8\u4e00",
#                     "value": 1406,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(32,154,13)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u62ce\u5305\u5165\u4f4f",
#                     "value": 991,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(124,109,132)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b0\u4e0a",
#                     "value": 5197,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(110,105,59)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6708\u79df",
#                     "value": 2871,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(142,0,99)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u72ec\u680b\u516c\u5bd3",
#                     "value": 6349,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(1,49,130)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u72ec\u7acb\u536b\u751f\u95f4",
#                     "value": 94,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(138,10,147)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u72ec\u7acb\u9633\u53f0",
#                     "value": 183,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(52,112,133)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7cbe\u88c5",
#                     "value": 2429,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(145,120,85)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8d1d\u58f3\u5b9e\u52d8",
#                     "value": 293,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(107,93,5)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8fd1\u5730\u94c1",
#                     "value": 18656,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(44,76,135)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9650\u5973\u751f",
#                     "value": 113,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(24,139,115)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9650\u7537\u751f",
#                     "value": 55,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(17,135,125)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u968f\u65f6\u770b\u623f",
#                     "value": 6746,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(127,73,140)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_7fddfbac13524e9e8f6aac72ca27f8b9.setOption(option_7fddfbac13524e9e8f6aac72ca27f8b9);
#
#     });
# </script>

# %%
sz_tag = []
for st in data[data['city']=='深圳'].dropna(subset=['house_tag'])['house_tag']:
    sz_tag.extend(st.split(' '))

name, value = WordCloud.cast(Counter(sz_tag))
wordcloud = WordCloud(width=500, height=500)
wordcloud.add("", name, value, word_size_range=[20, 100])
wordcloud
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="8f7d5a2b5b744dada95abec4d4588a1a" style="width:500px;height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_8f7d5a2b5b744dada95abec4d4588a1a = echarts.init(document.getElementById('8f7d5a2b5b744dada95abec4d4588a1a'), null, {renderer: 'canvas'});
# var option_8f7d5a2b5b744dada95abec4d4588a1a = {
#     "title": [
#         {
#             "text": "",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 491881,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u516c\u5bd3",
#                     "value": 2784,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(110,146,112)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53cc\u536b\u751f\u95f4",
#                     "value": 936,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(29,26,78)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u62bc\u4e00\u4ed8\u4e00",
#                     "value": 3142,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(94,130,50)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u62ce\u5305\u5165\u4f4f",
#                     "value": 1449,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(28,42,61)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b0\u4e0a",
#                     "value": 3301,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(38,0,145)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6708\u79df",
#                     "value": 3664,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(157,89,23)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u72ec\u680b\u516c\u5bd3",
#                     "value": 7148,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(142,27,47)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u72ec\u7acb\u536b\u751f\u95f4",
#                     "value": 259,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(7,95,118)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u72ec\u7acb\u9633\u53f0",
#                     "value": 466,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(137,91,119)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7cbe\u88c5",
#                     "value": 4834,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(34,11,54)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8fd1\u5730\u94c1",
#                     "value": 12812,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(15,54,21)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9650\u5973\u751f",
#                     "value": 52,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(131,77,78)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9650\u7537\u751f",
#                     "value": 24,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(63,100,127)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u968f\u65f6\u770b\u623f",
#                     "value": 7478,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(87,54,46)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_8f7d5a2b5b744dada95abec4d4588a1a.setOption(option_8f7d5a2b5b744dada95abec4d4588a1a);
#
#     });
# </script>
